# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 602

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
    url = f'https://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units=imperial&q={city}'
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_response = requests.get(url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_response["coord"]["lat"]
        city_lng = city_response["coord"]["lon"]
        city_max_temp = city_response["main"]["temp_max"]
        city_humidity = city_response["main"]["humidity"]
        city_clouds = city_response["clouds"]["all"]
        city_wind = city_response["wind"]["speed"]
        city_country = city_response["sys"]["country"]
        city_date = city_response["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except Exception as e:
        print(f"Error processing {city}: {str(e)}")
        print("City not found. Skipping...")
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | queenstown
# Processing Record 2 of Set 1 | grytviken
# Processing Record 3 of Set 1 | blackmans bay
# Processing Record 4 of Set 1 | pakpattan
# Processing Record 5 of Set 1 | port-aux-francais
# Processing Record 6 of Set 1 | avarua
# Processing Record 7 of Set 1 | west island
# Processing Record 8 of Set 1 | san antonio de pale
# Processing Record 9 of Set 1 | upper grand lagoon
# Processing Record 10 of Set 1 | adamstown
# Processing Record 11 of Set 1 | hithadhoo
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | puerto ayora
# Processing Record 14 of Set 1 | iqaluit
# Processing Record 15 of Set 1 | mil'kovo
# Processing Record 16 of Set 1 | natal
# Processing Record 17 of Set 1 | nguti
# Processing Record 18 of Set 1 | pisco
# Processing Record 19 of Set 1 | qaqortoq
# Processing Record 20 of Set 1 | jamestown
# Processing Record 21 of Set 1 | papatowai
# Processing Record 22 of Set 1 | smithfield
# Processing Record 23 of Set 1 | port alfred
# Processing Record 24 of Set 1 | christchurch
# Processing Record 25 of Set 1 | ravar
# Processing Record 26 of Set 1 | bredasdorp
# Processing Record 27 of Set 1 | wewak
# Processing Record 28 of Set 1 | edinburgh of the seven seas
# Processing Record 29 of Set 1 | kapuskasing
# Processing Record 30 of Set 1 | oyem
# Processing Record 31 of Set 1 | longyearbyen
# Processing Record 32 of Set 1 | chonchi
# Processing Record 33 of Set 1 | les cayes
# Processing Record 34 of Set 1 | bethel
# Processing Record 35 of Set 1 | mirny
# Processing Record 36 of Set 1 | utrik
# Processing Record 37 of Set 1 | ushuaia
# Processing Record 38 of Set 1 | ilulissat
# Processing Record 39 of Set 1 | cable beach
# Error processing cable beach: 'coord'
# City not found. Skipping...
# Processing Record 40 of Set 1 | lihue
# Processing Record 41 of Set 1 | berdigestyakh
# Processing Record 42 of Set 1 | dzhetygara
# Processing Record 43 of Set 1 | mtambile
# Processing Record 44 of Set 1 | kafr laha
# Processing Record 45 of Set 1 | nemuro
# Processing Record 46 of Set 1 | port mathurin
# Processing Record 47 of Set 1 | stanley
# Processing Record 48 of Set 1 | badger
# Processing Record 49 of Set 1 | colonia
# Processing Record 50 of Set 1 | espargos
# Error processing espargos: 'coord'
# City not found. Skipping...
# Processing Record 0 of Set 2 | torquay
# Processing Record 1 of Set 2 | enewetak
# Processing Record 2 of Set 2 | dudinka
# Processing Record 3 of Set 2 | margaret river
# Processing Record 4 of Set 2 | nagqu
# Processing Record 5 of Set 2 | polyarnyy
# Processing Record 6 of Set 2 | guerrero negro
# Processing Record 7 of Set 2 | fisterra
# Processing Record 8 of Set 2 | brandfort
# Processing Record 9 of Set 2 | tahe
# Processing Record 10 of Set 2 | fortuna
# Processing Record 11 of Set 2 | hawaiian paradise park
# Processing Record 12 of Set 2 | cidreira
# Processing Record 13 of Set 2 | waitangi
# Processing Record 14 of Set 2 | thompson
# Processing Record 15 of Set 2 | sitka
# Processing Record 16 of Set 2 | bandrele
# Processing Record 17 of Set 2 | new norfolk
# Processing Record 18 of Set 2 | antonio enes
# Processing Record 19 of Set 2 | holualoa
# Processing Record 20 of Set 2 | mwingi
# Processing Record 21 of Set 2 | westport
# Processing Record 22 of Set 2 | ribeira grande
# Processing Record 23 of Set 2 | villa gesell
# Processing Record 24 of Set 2 | vadso
# Processing Record 25 of Set 2 | tobelo
# Processing Record 26 of Set 2 | taiohae
# Error processing taiohae: 'coord'
# City not found. Skipping...
# Processing Record 27 of Set 2 | olinda
# Processing Record 28 of Set 2 | puerto natales
# Processing Record 29 of Set 2 | prado
# Processing Record 30 of Set 2 | cabo san lucas
# Processing Record 31 of Set 2 | quellon
# Processing Record 32 of Set 2 | yellowknife
# Processing Record 33 of Set 2 | bechar
# Processing Record 34 of Set 2 | vilyuysk
# Processing Record 35 of Set 2 | remire-montjoly
# Processing Record 36 of Set 2 | ola
# Processing Record 37 of Set 2 | ujkigyos
# Processing Record 38 of Set 2 | petoskey
# Processing Record 39 of Set 2 | alice springs
# Processing Record 40 of Set 2 | kualakapuas
# Processing Record 41 of Set 2 | tiksi
# Processing Record 42 of Set 2 | sao vicente
# Processing Record 43 of Set 2 | mount gambier
# Processing Record 44 of Set 2 | isafjordur
# Processing Record 45 of Set 2 | arteche
# Processing Record 46 of Set 2 | alo
# Processing Record 47 of Set 2 | karkira
# Processing Record 48 of Set 2 | sukumo
# Processing Record 49 of Set 2 | nautanwa
# Processing Record 0 of Set 3 | yenifakili
# Processing Record 1 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 2 of Set 3 | flying fish cove
# Processing Record 3 of Set 3 | buraydah
# Processing Record 4 of Set 3 | kielce
# Processing Record 5 of Set 3 | iskateley
# Processing Record 6 of Set 3 | yeppoon
# Processing Record 7 of Set 3 | hasaki
# Processing Record 8 of Set 3 | oranjemund
# Processing Record 9 of Set 3 | lebu
# Processing Record 10 of Set 3 | hihifo
# Error processing hihifo: 'coord'
# City not found. Skipping...
# Processing Record 11 of Set 3 | saipan
# Processing Record 12 of Set 3 | jinchang
# Processing Record 13 of Set 3 | anadyr
# Processing Record 14 of Set 3 | vila do maio
# Processing Record 15 of Set 3 | luderitz
# Processing Record 16 of Set 3 | the pas
# Processing Record 17 of Set 3 | lazaro cardenas
# Processing Record 18 of Set 3 | lata
# Processing Record 19 of Set 3 | portland
# Processing Record 20 of Set 3 | kuraymah
# Processing Record 21 of Set 3 | port-vila
# Processing Record 22 of Set 3 | la passe
# Processing Record 23 of Set 3 | port elizabeth
# Processing Record 24 of Set 3 | krzeszowice
# Processing Record 25 of Set 3 | laguna
# Processing Record 26 of Set 3 | susuman
# Processing Record 27 of Set 3 | abraham's bay
# Error processing abraham's bay: 'coord'
# City not found. Skipping...
# Processing Record 28 of Set 3 | chernyshevskiy
# Processing Record 29 of Set 3 | mejit
# Processing Record 30 of Set 3 | takoradi
# Processing Record 31 of Set 3 | crane
# Processing Record 32 of Set 3 | nova sintra
# Processing Record 33 of Set 3 | tinajo
# Processing Record 34 of Set 3 | wailua homesteads
# Processing Record 35 of Set 3 | karaisali
# Processing Record 36 of Set 3 | fort mcmurray
# Processing Record 37 of Set 3 | pascagoula
# Processing Record 38 of Set 3 | vorkuta
# Processing Record 39 of Set 3 | georgetown
# Processing Record 40 of Set 3 | atafu village
# Processing Record 41 of Set 3 | tsivil'sk
# Processing Record 42 of Set 3 | sao gabriel da cachoeira
# Processing Record 43 of Set 3 | tosontsengel
# Processing Record 44 of Set 3 | east london
# Processing Record 45 of Set 3 | bilibino
# Processing Record 46 of Set 3 | arkhangel'sk
# Processing Record 47 of Set 3 | marudi
# Error processing marudi: 'coord'
# City not found. Skipping...
# Processing Record 48 of Set 3 | novaya igirma
# Processing Record 49 of Set 3 | kibre mengist
# Processing Record 0 of Set 4 | mayen abun
# Error processing mayen abun: 'coord'
# City not found. Skipping...
# Processing Record 1 of Set 4 | cafayate
# Processing Record 2 of Set 4 | rundu
# Processing Record 3 of Set 4 | constantia
# Processing Record 4 of Set 4 | kapit
# Processing Record 5 of Set 4 | banyo
# Processing Record 6 of Set 4 | malvan
# Processing Record 7 of Set 4 | castillos
# Processing Record 8 of Set 4 | ponta delgada
# Processing Record 9 of Set 4 | margate
# Processing Record 10 of Set 4 | dongsheng
# Processing Record 11 of Set 4 | hermanus
# Processing Record 12 of Set 4 | vingt cinq
# Error processing vingt cinq: 'coord'
# City not found. Skipping...
# Processing Record 13 of Set 4 | ust-nera
# Processing Record 14 of Set 4 | kurmuk
# Processing Record 15 of Set 4 | keren
# Processing Record 16 of Set 4 | invercargill
# Processing Record 17 of Set 4 | puerto san carlos
# Error processing puerto san carlos: 'coord'
# City not found. Skipping...
# Processing Record 18 of Set 4 | mabaruma
# Processing Record 19 of Set 4 | miquelon
# Processing Record 20 of Set 4 | keflavik
# Processing Record 21 of Set 4 | znamenskoye
# Processing Record 22 of Set 4 | port moresby
# Processing Record 23 of Set 4 | geraldton
# Processing Record 24 of Set 4 | tsiombe
# Processing Record 25 of Set 4 | saurimo
# Processing Record 26 of Set 4 | namibe
# Processing Record 27 of Set 4 | olonkinbyen
# Processing Record 28 of Set 4 | vorgashor
# Processing Record 29 of Set 4 | kayangel
# Processing Record 30 of Set 4 | alesund
# Processing Record 31 of Set 4 | college
# Processing Record 32 of Set 4 | lewistown
# Processing Record 33 of Set 4 | punta arenas
# Processing Record 34 of Set 4 | gorontalo
# Processing Record 35 of Set 4 | moose jaw
# Processing Record 36 of Set 4 | nabire
# Processing Record 37 of Set 4 | arawa
# Processing Record 38 of Set 4 | kodiak
# Processing Record 39 of Set 4 | el bayadh
# Processing Record 40 of Set 4 | klyuchi
# Processing Record 41 of Set 4 | kununurra
# Processing Record 42 of Set 4 | ancud
# Processing Record 43 of Set 4 | coquimbo
# Processing Record 44 of Set 4 | kuqa
# Processing Record 45 of Set 4 | tolanaro
# Processing Record 46 of Set 4 | inhambane
# Processing Record 47 of Set 4 | brookings
# Processing Record 48 of Set 4 | yeniseysk
# Processing Record 49 of Set 4 | qarauyl
# Processing Record 0 of Set 5 | viseu
# Processing Record 1 of Set 5 | puerto madero
# Processing Record 2 of Set 5 | zhanaozen
# Processing Record 3 of Set 5 | ujae
# Processing Record 4 of Set 5 | ha'il
# Processing Record 5 of Set 5 | micheweni
# Processing Record 6 of Set 5 | happy valley-goose bay
# Processing Record 7 of Set 5 | santa cruz de tenerife
# Processing Record 8 of Set 5 | marka
# Processing Record 9 of Set 5 | panguipulli
# Processing Record 10 of Set 5 | nurota
# Processing Record 11 of Set 5 | fale old settlement
# Processing Record 12 of Set 5 | diego martin
# Processing Record 13 of Set 5 | mahina
# Processing Record 14 of Set 5 | angel r. cabada
# Processing Record 15 of Set 5 | gejiu
# Processing Record 16 of Set 5 | kolpashevo
# Processing Record 17 of Set 5 | vila franca do campo
# Processing Record 18 of Set 5 | can
# Processing Record 19 of Set 5 | peebles
# Processing Record 20 of Set 5 | haiku-pauwela
# Processing Record 21 of Set 5 | nagato
# Processing Record 22 of Set 5 | waterford
# Processing Record 23 of Set 5 | tashla
# Processing Record 24 of Set 5 | aras-asan
# Processing Record 25 of Set 5 | palmer
# Processing Record 26 of Set 5 | malka
# Processing Record 27 of Set 5 | mariinsk
# Processing Record 28 of Set 5 | meads
# Processing Record 29 of Set 5 | rio grande
# Processing Record 30 of Set 5 | neiafu
# Processing Record 31 of Set 5 | praia da vitoria
# Processing Record 32 of Set 5 | nadym
# Processing Record 33 of Set 5 | anaconda
# Processing Record 34 of Set 5 | minab
# Processing Record 35 of Set 5 | mogocha
# Processing Record 36 of Set 5 | tamanrasset
# Processing Record 37 of Set 5 | nantucket
# Processing Record 38 of Set 5 | abu 'arish
# Error processing abu 'arish: 'coord'
# City not found. Skipping...
# Processing Record 39 of Set 5 | narok
# Processing Record 40 of Set 5 | whitehorse
# Processing Record 41 of Set 5 | kingscliff
# Processing Record 42 of Set 5 | zouerate
# Processing Record 43 of Set 5 | kisesa
# Processing Record 44 of Set 5 | howrah
# Processing Record 45 of Set 5 | betim
# Processing Record 46 of Set 5 | devinuwara
# Error processing devinuwara: 'coord'
# City not found. Skipping...
# Processing Record 47 of Set 5 | swansea
# Processing Record 48 of Set 5 | pandan
# Processing Record 49 of Set 5 | paradip garh
# Processing Record 0 of Set 6 | hammerfest
# Processing Record 1 of Set 6 | tranovaho
# Error processing tranovaho: 'coord'
# City not found. Skipping...
# Processing Record 2 of Set 6 | jean-rabel
# Processing Record 3 of Set 6 | kruisfontein
# Processing Record 4 of Set 6 | kerikeri
# Processing Record 5 of Set 6 | pyriatyn
# Processing Record 6 of Set 6 | fort bragg
# Processing Record 7 of Set 6 | nelson
# Processing Record 8 of Set 6 | uturoa
# Processing Record 9 of Set 6 | kolondieba
# Processing Record 10 of Set 6 | chulym
# Processing Record 11 of Set 6 | walvis bay
# Processing Record 12 of Set 6 | callao
# Processing Record 13 of Set 6 | pacific grove
# Processing Record 14 of Set 6 | pyhajarvi
# Processing Record 15 of Set 6 | arauco
# Processing Record 16 of Set 6 | zalingei
# Processing Record 17 of Set 6 | ormara
# Processing Record 18 of Set 6 | nizhneudinsk
# Processing Record 19 of Set 6 | manoharpur
# Processing Record 20 of Set 6 | saint-joseph
# Processing Record 21 of Set 6 | ghadamis
# Processing Record 22 of Set 6 | am djarass
# Error processing am djarass: 'coord'
# City not found. Skipping...
# Processing Record 23 of Set 6 | windhoek
# Processing Record 24 of Set 6 | xai-xai
# Processing Record 25 of Set 6 | ulladulla
# Processing Record 26 of Set 6 | talnakh
# Processing Record 27 of Set 6 | puerto san jose
# Processing Record 28 of Set 6 | shakawe
# Processing Record 29 of Set 6 | horta
# Processing Record 30 of Set 6 | nkove
# Processing Record 31 of Set 6 | isangel
# Processing Record 32 of Set 6 | san francisco de la paz
# Processing Record 33 of Set 6 | ardanuc
# Processing Record 34 of Set 6 | tralee
# Processing Record 35 of Set 6 | kintampo
# Processing Record 36 of Set 6 | saint-pierre
# Processing Record 37 of Set 6 | biltine
# Processing Record 38 of Set 6 | kotma
# Processing Record 39 of Set 6 | gusev
# Processing Record 40 of Set 6 | kakching
# Processing Record 41 of Set 6 | forres
# Processing Record 42 of Set 6 | tura
# Processing Record 43 of Set 6 | hotan
# Processing Record 44 of Set 6 | saint croix
# Processing Record 45 of Set 6 | belmonte
# Processing Record 46 of Set 6 | mirnyy
# Processing Record 47 of Set 6 | ocozocoautla de espinosa
# Processing Record 48 of Set 6 | chifeng
# Processing Record 49 of Set 6 | karamay
# Error processing karamay: 'coord'
# City not found. Skipping...
# Processing Record 0 of Set 7 | piacabucu
# Processing Record 1 of Set 7 | wynyard
# Processing Record 2 of Set 7 | el nido
# Processing Record 3 of Set 7 | sol'tsy
# Processing Record 4 of Set 7 | phalaborwa
# Processing Record 5 of Set 7 | aasiaat
# Processing Record 6 of Set 7 | hamilton
# Processing Record 7 of Set 7 | campoverde
# Processing Record 8 of Set 7 | lancaster
# Processing Record 9 of Set 7 | hadibu
# Processing Record 10 of Set 7 | kill devil hills
# Processing Record 11 of Set 7 | kourou
# Processing Record 12 of Set 7 | arantangi
# Processing Record 13 of Set 7 | desaguadero
# Processing Record 14 of Set 7 | st. john's
# Processing Record 15 of Set 7 | battagram
# Processing Record 16 of Set 7 | poteau
# Processing Record 17 of Set 7 | huntsville
# Processing Record 18 of Set 7 | ixtapa
# Processing Record 19 of Set 7 | harar
# Processing Record 20 of Set 7 | mahibadhoo
# Processing Record 21 of Set 7 | bubaque
# Processing Record 22 of Set 7 | kavalerovo
# Processing Record 23 of Set 7 | cockburn town
# Processing Record 24 of Set 7 | peterhead
# Processing Record 25 of Set 7 | malabar
# Processing Record 26 of Set 7 | bangassou
# Processing Record 27 of Set 7 | rongelap
# Processing Record 28 of Set 7 | alofi
# Processing Record 29 of Set 7 | mitu
# Processing Record 30 of Set 7 | carnarvon
# Processing Record 31 of Set 7 | baoding
# Processing Record 32 of Set 7 | palikir - national government center
# Processing Record 33 of Set 7 | mar del plata
# Processing Record 34 of Set 7 | gosaba
# Error processing gosaba: 'coord'
# City not found. Skipping...
# Processing Record 35 of Set 7 | cannonvale
# Processing Record 36 of Set 7 | san patricio
# Processing Record 37 of Set 7 | oltinko'l
# Processing Record 38 of Set 7 | stroitel'
# Processing Record 39 of Set 7 | san jose village
# Error processing san jose village: 'coord'
# City not found. Skipping...
# Processing Record 40 of Set 7 | sisimiut
# Processing Record 41 of Set 7 | brisas de zicatela
# Processing Record 42 of Set 7 | sao desiderio
# Processing Record 43 of Set 7 | padang
# Processing Record 44 of Set 7 | clinton
# Processing Record 45 of Set 7 | selfoss
# Processing Record 46 of Set 7 | nizhniy odes
# Processing Record 47 of Set 7 | neon karlovasion
# Processing Record 48 of Set 7 | udachny
# Processing Record 49 of Set 7 | nuuk
# Processing Record 0 of Set 8 | wuxi
# Processing Record 1 of Set 8 | aioun
# Processing Record 2 of Set 8 | dryden
# Processing Record 3 of Set 8 | zheleznogorsk-ilimskiy
# Processing Record 4 of Set 8 | pokhara
# Processing Record 5 of Set 8 | yuzhno-kurilsk
# Processing Record 6 of Set 8 | kokemaki
# Processing Record 7 of Set 8 | iwanai
# Processing Record 8 of Set 8 | coihueco
# Processing Record 9 of Set 8 | pangai
# Processing Record 10 of Set 8 | morehead city
# Processing Record 11 of Set 8 | veraval
# Processing Record 12 of Set 8 | chadan
# Processing Record 13 of Set 8 | ahmadpur east
# Processing Record 14 of Set 8 | smithers
# Processing Record 15 of Set 8 | puerto baquerizo moreno
# Processing Record 16 of Set 8 | vilyuchinsk
# Processing Record 17 of Set 8 | sebastopol
# Processing Record 18 of Set 8 | childress
# Processing Record 19 of Set 8 | greenville
# Processing Record 20 of Set 8 | naryn
# Processing Record 21 of Set 8 | shitanjing
# Processing Record 22 of Set 8 | kindberg
# Processing Record 23 of Set 8 | rabo de peixe
# Processing Record 24 of Set 8 | arraial do cabo
# Processing Record 25 of Set 8 | selkirk
# Processing Record 26 of Set 8 | egilsstadir
# Processing Record 27 of Set 8 | bayramaly
# Processing Record 28 of Set 8 | lohr am main
# Processing Record 29 of Set 8 | laurel
# Processing Record 30 of Set 8 | kailua-kona
# Processing Record 31 of Set 8 | bintulu
# Processing Record 32 of Set 8 | lompoc
# Processing Record 33 of Set 8 | ketchikan
# Processing Record 34 of Set 8 | bikenibeu village
# Processing Record 35 of Set 8 | mulki
# Processing Record 36 of Set 8 | lautoka
# Processing Record 37 of Set 8 | kurumkan
# Processing Record 38 of Set 8 | el calafate
# Processing Record 39 of Set 8 | puttalam
# Processing Record 40 of Set 8 | gokwe
# Processing Record 41 of Set 8 | uusikaupunki
# Processing Record 42 of Set 8 | bastia
# Processing Record 43 of Set 8 | chimbote
# Processing Record 44 of Set 8 | ilinge
# Processing Record 45 of Set 8 | noumea
# Processing Record 46 of Set 8 | dawesville
# Processing Record 47 of Set 8 | jiwani
# Processing Record 48 of Set 8 | tozkhurmato
# Processing Record 49 of Set 8 | fuvahmulah
# Error processing fuvahmulah: 'coord'
# City not found. Skipping...
# Processing Record 0 of Set 9 | talakan
# Processing Record 1 of Set 9 | bermejillo
# Processing Record 2 of Set 9 | kangding
# Processing Record 3 of Set 9 | taunggyi
# Processing Record 4 of Set 9 | gadzhiyevo
# Processing Record 5 of Set 9 | kupang
# Processing Record 6 of Set 9 | grantsville
# Processing Record 7 of Set 9 | nizhniy kuranakh
# Processing Record 8 of Set 9 | priekuli
# Error processing priekuli: 'coord'
# City not found. Skipping...
# Processing Record 9 of Set 9 | hanceville
# Processing Record 10 of Set 9 | hovd
# Processing Record 11 of Set 9 | naantali
# Processing Record 12 of Set 9 | tocopilla
# Processing Record 13 of Set 9 | tadine
# Processing Record 14 of Set 9 | lycksele
# Processing Record 15 of Set 9 | ilongero
# Processing Record 16 of Set 9 | kidal
# Processing Record 17 of Set 9 | sao joao da barra
# Processing Record 18 of Set 9 | nadi
# Processing Record 19 of Set 9 | kaa-khem
# Processing Record 20 of Set 9 | soledar
# Processing Record 21 of Set 9 | kragero
# Processing Record 22 of Set 9 | sijunjung
# Processing Record 23 of Set 9 | severo-yeniseyskiy
# Processing Record 24 of Set 9 | mandalgovi
# Processing Record 25 of Set 9 | ouro sogui
# Processing Record 26 of Set 9 | port saint john's
# Processing Record 27 of Set 9 | mulayjah
# Processing Record 28 of Set 9 | dunedin
# Processing Record 29 of Set 9 | ust'-ilimsk
# Processing Record 30 of Set 9 | sandnessjoen
# Processing Record 31 of Set 9 | ta`u
# Processing Record 32 of Set 9 | mahajanga
# Processing Record 33 of Set 9 | buala
# Processing Record 34 of Set 9 | dinghaicun
# Processing Record 35 of Set 9 | ofunato
# Processing Record 36 of Set 9 | gazojak
# Processing Record 37 of Set 9 | mount pearl
# Processing Record 38 of Set 9 | soio
# Processing Record 39 of Set 9 | gornozavodsk
# Processing Record 40 of Set 9 | cromer
# Processing Record 41 of Set 9 | khash
# Processing Record 42 of Set 9 | kirakira
# Processing Record 43 of Set 9 | puerto lempira
# Processing Record 44 of Set 9 | bandarbeyla
# Processing Record 45 of Set 9 | chumphon
# Processing Record 46 of Set 9 | chinsali
# Processing Record 47 of Set 9 | i-n-salah
# Processing Record 48 of Set 9 | saynshand
# Processing Record 49 of Set 9 | napier
# Processing Record 0 of Set 10 | dompu
# Processing Record 1 of Set 10 | tazovsky
# Processing Record 2 of Set 10 | shanhaiguan
# Processing Record 3 of Set 10 | san lawrenz
# Processing Record 4 of Set 10 | afaahiti
# Processing Record 5 of Set 10 | labrador city
# Processing Record 6 of Set 10 | pangody
# Processing Record 7 of Set 10 | benguela
# Processing Record 8 of Set 10 | kisangani
# Processing Record 9 of Set 10 | kolonia
# Processing Record 10 of Set 10 | coahuayana de hidalgo
# Processing Record 11 of Set 10 | leh
# Processing Record 12 of Set 10 | dhanera
# Processing Record 13 of Set 10 | loa janan
# Processing Record 14 of Set 10 | khanty-mansiysk
# Processing Record 15 of Set 10 | preobrazheniye
# Processing Record 16 of Set 10 | carutapera
# Processing Record 17 of Set 10 | baikunthpur
# Processing Record 18 of Set 10 | barcelos
# Processing Record 19 of Set 10 | youkounkoun
# Processing Record 20 of Set 10 | toga village
# Error processing toga village: 'coord'
# City not found. Skipping...
# Processing Record 21 of Set 10 | codrington
# Processing Record 22 of Set 10 | yichang
# Processing Record 23 of Set 10 | hilo
# Processing Record 24 of Set 10 | eraan
# Processing Record 25 of Set 10 | fuglafjordur
# Processing Record 26 of Set 10 | bargara
# Error processing bargara: 'coord'
# City not found. Skipping...
# Processing Record 27 of Set 10 | craig
# Processing Record 28 of Set 10 | tondano
# Processing Record 29 of Set 10 | forster
# Processing Record 30 of Set 10 | timaru
# Processing Record 31 of Set 10 | medicine hat
# Processing Record 32 of Set 10 | harper
# Processing Record 33 of Set 10 | viligili
# Error processing viligili: 'coord'
# City not found. Skipping...
# Processing Record 34 of Set 10 | mogadishu
# Processing Record 35 of Set 10 | cedeira
# Processing Record 36 of Set 10 | saint-philippe
# Processing Record 37 of Set 10 | haimen
# Processing Record 38 of Set 10 | tannum sands
# Processing Record 39 of Set 10 | begoro
# Processing Record 40 of Set 10 | raduzhnyy
# Processing Record 41 of Set 10 | beira
# Processing Record 42 of Set 10 | beteza
# Error processing beteza: 'coord'
# City not found. Skipping...
# Processing Record 43 of Set 10 | nouadhibou
# Processing Record 44 of Set 10 | nar'yan-mar
# Processing Record 45 of Set 10 | salinas
# Processing Record 46 of Set 10 | masuguru
# Processing Record 47 of Set 10 | spring creek
# Processing Record 48 of Set 10 | island harbour
# Processing Record 49 of Set 10 | 'anat al qadimah
# Processing Record 0 of Set 11 | nampula
# Processing Record 1 of Set 11 | kenai
# Processing Record 2 of Set 11 | manaure
# Processing Record 3 of Set 11 | beipiao
# Processing Record 4 of Set 11 | progreso
# Processing Record 5 of Set 11 | bonthe
# Processing Record 6 of Set 11 | weno
# Processing Record 7 of Set 11 | seoni malwa
# Processing Record 8 of Set 11 | las veredas
# Processing Record 9 of Set 11 | dombarovskiy
# Processing Record 10 of Set 11 | setti fatma
# Error processing setti fatma: 'coord'
# City not found. Skipping...
# Processing Record 11 of Set 11 | karratha
# Processing Record 12 of Set 11 | seneca
# Processing Record 13 of Set 11 | kingston
# Processing Record 14 of Set 11 | ketou
# Processing Record 15 of Set 11 | zuenoula
# Processing Record 16 of Set 11 | richards bay
# Processing Record 17 of Set 11 | poronaysk
# Processing Record 18 of Set 11 | serafimovich
# Processing Record 19 of Set 11 | khandyga
# Processing Record 20 of Set 11 | yangor
# Error processing yangor: 'coord'
# City not found. Skipping...
# Processing Record 21 of Set 11 | sayyan
# Processing Record 22 of Set 11 | leava
# Processing Record 23 of Set 11 | phang nga
# Processing Record 24 of Set 11 | kerben
# Processing Record 25 of Set 11 | zhigulevsk
# Processing Record 26 of Set 11 | pimenta bueno
# Processing Record 27 of Set 11 | mugia
# Processing Record 28 of Set 11 | vung tau
# Processing Record 29 of Set 11 | yichun
# Processing Record 30 of Set 11 | labytnangi
# Processing Record 31 of Set 11 | greymouth
# Processing Record 32 of Set 11 | novyy urengoy
# Processing Record 33 of Set 11 | vega de alatorre
# Processing Record 34 of Set 11 | chibougamau
# Processing Record 35 of Set 11 | oyama
# Processing Record 36 of Set 11 | hola
# Processing Record 37 of Set 11 | usinsk
# Processing Record 38 of Set 11 | chapaev
# Processing Record 39 of Set 11 | aykhal
# Processing Record 40 of Set 11 | ulsteinvik
# Processing Record 41 of Set 11 | duncan
# Processing Record 42 of Set 11 | howard springs
# Processing Record 43 of Set 11 | port lincoln
# Processing Record 44 of Set 11 | nyurba
# Processing Record 45 of Set 11 | concordia
# Processing Record 46 of Set 11 | patnanungan
# Processing Record 47 of Set 11 | alotau
# Error processing alotau: 'coord'
# City not found. Skipping...
# Processing Record 48 of Set 11 | berezovyy
# Processing Record 49 of Set 11 | kitami
# Processing Record 0 of Set 12 | ouellah
# Error processing ouellah: 'coord'
# City not found. Skipping...
# Processing Record 1 of Set 12 | muisne
# Processing Record 2 of Set 12 | marion
# Processing Record 3 of Set 12 | arish
# Processing Record 4 of Set 12 | mili
# Processing Record 5 of Set 12 | alzamay
# Processing Record 6 of Set 12 | calvi
# Processing Record 7 of Set 12 | upata
# Processing Record 8 of Set 12 | ahar
# Processing Record 9 of Set 12 | sonsorol village
# Error processing sonsorol village: 'coord'
# City not found. Skipping...
# Processing Record 10 of Set 12 | starobil's'k
# Processing Record 11 of Set 12 | toliara
# Processing Record 12 of Set 12 | waterloo
# Processing Record 13 of Set 12 | cookeville
# Processing Record 14 of Set 12 | lerwick
# Processing Record 15 of Set 12 | kandla
# Processing Record 16 of Set 12 | altai
# Processing Record 17 of Set 12 | zhangye
# Processing Record 18 of Set 12 | flekkefjord
# Processing Record 19 of Set 12 | krasnyy yar
# Processing Record 20 of Set 12 | formosa
# Processing Record 21 of Set 12 | ufa
# Processing Record 22 of Set 12 | yantongshan
# Processing Record 23 of Set 12 | at taj
# Processing Record 24 of Set 12 | timimoun
# Processing Record 25 of Set 12 | patnos
# Processing Record 26 of Set 12 | vernon
# Processing Record 27 of Set 12 | turpan
# Processing Record 28 of Set 12 | nioki
# Processing Record 29 of Set 12 | pangobilian
# Processing Record 30 of Set 12 | naze
# Processing Record 31 of Set 12 | la ronge
# Processing Record 32 of Set 12 | al hawatah
# Processing Record 33 of Set 12 | broome
# Processing Record 34 of Set 12 | oppdal
# Processing Record 35 of Set 12 | minas de marcona
# Processing Record 36 of Set 12 | dawson creek
# Processing Record 37 of Set 12 | leksand
# Processing Record 38 of Set 12 | bereket
# Processing Record 39 of Set 12 | tobol'sk
# Processing Record 40 of Set 12 | nuporanga
# Processing Record 41 of Set 12 | cortez
# Processing Record 42 of Set 12 | laikit, laikit ii (dimembe)
# Processing Record 43 of Set 12 | bodaybo
# Processing Record 44 of Set 12 | tahoua
# Processing Record 45 of Set 12 | buenavista de cuellar
# Processing Record 46 of Set 12 | antsiranana
# Processing Record 47 of Set 12 | adrogue
# Error processing adrogue: 'coord'
# City not found. Skipping...
# Processing Record 48 of Set 12 | neustadt an der aisch
# Processing Record 49 of Set 12 | zanjan
# Processing Record 0 of Set 13 | mugumu
# Processing Record 1 of Set 13 | caras
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          574
# Lat           574
# Lng           574
# Max Temp      574
# Humidity      574
# Cloudiness    574
# Wind Speed    574
# Country       574
# Date          574
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         queenstown -31.8976   26.8753     61.27        66          58
# 1          grytviken -54.2811  -36.5092     35.26        87         100
# 2      blackmans bay -43.0167  147.3167     65.73        54          51
# 3          pakpattan  30.3410   73.3866     45.64        41          71
# 4  port-aux-francais -49.3500   70.2167     43.56        72          82
#
#    Wind Speed Country        Date
# 0        8.70      ZA  1709596862
# 1       18.72      GS  1709596759
# 2        1.99      AU  1709596865
# 3        4.05      PK  1709596866
# 4       31.70      TF  1709596868

# %%
# Export the City_Data into a csv
city_data_df.to_csv("cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               faya  18.3851   42.4509     22.06        35          21
# 1            farsund  58.0948    6.8047     13.30       100           0
# 2        new norfolk -42.7826  147.0587     11.72        58          12
# 3          jamestown  42.0970  -79.2353      5.77        77         100
# 4            lanzhou  36.0564  103.7922     14.53        48          59
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      SA  1666108228
# 1              7.65      NO  1666108228
# 2              1.34      AU  1666108230
# 3              9.77      US  1666107934
# 4              1.20      CN  1666108230

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], alpha=0.5)  

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (°C)') 
plt.title('City Max Latitude vs. Temperature Scatter Plot 2022-10-18')

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], alpha=0.5)  

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humidity') 
plt.title('City Latitude vs. Humidity')

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], alpha=0.5)  

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness') 
plt.title(' City Latitude vs. Cloudiness (2022-10-18)')

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], alpha=0.5)  

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')  
plt.title('City Latitude vs. Wind Speed')

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
import seaborn as sns

def linear_regression_plot(x, y, title, x_label, y_label):
    sns.regplot(x=x, y=y, scatter_kws={'alpha':0.5})

    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)

    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             faya  18.3851   42.4509     22.06        35          21
# 1          farsund  58.0948    6.8047     13.30       100           0
# 3        jamestown  42.0970  -79.2353      5.77        77         100
# 4          lanzhou  36.0564  103.7922     14.53        48          59
# 6           albany  42.6001  -73.9662     10.36        74          29
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      SA  1666108228
# 1              7.65      NO  1666108228
# 3              9.77      US  1666107934
# 4              1.20      CN  1666108230
# 6              2.10      US  1666108231

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]


# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2         new norfolk -42.7826  147.0587     11.72        58          12
# 5             ushuaia -54.8000  -68.3000      8.81        81          75
# 7           carnarvon -24.8667  113.6333     20.02        76           0
# 9        saint-pierre -21.3393   55.4781     22.82        68           0
# 10           colorado -22.8375  -51.9731     20.36        86          96
#
#          Wind Speed Country        Date
# City_ID
# 2              1.34      AU  1666108230
# 5              3.09      AR  1666108231
# 7              7.46      AU  1666108232
# 9              5.14      RE  1666108236
# 10             4.69      BR  1666107965

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere Import Stats Model
import statsmodels.api as sm

# Set Up Columns
x_column = 'Lat'
y_column = 'Max Temp'

# Create a linear regression plot for the Northern Hemisphere
sns.regplot(x=x_column, y=y_column, data=northern_hemi_df, scatter_kws={'alpha': 0.5})

X = sm.add_constant(northern_hemi_df[x_column]) 
model = sm.OLS(northern_hemi_df[y_column], X).fit()

intercept, slope = model.params['const'], model.params[x_column]

# Add Labels
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.title('Northern Hemisphere - Linear Regression: {} vs. {}'.format(x_column, y_column))

equation_text = 'Equation: {} = {:.2f} + {:.2f} * {}'.format(y_column, intercept, slope, x_column)
plt.annotate(equation_text, xy=(0.05, 0.95), xycoords='axes fraction', fontsize=10, ha='left')

# Show Plot
plt.show()

# %%
# Linear regression on Southern Hemisphere Import Stats Model
import statsmodels.api as sm

#Define Columns
x_column = 'Lat'
y_column = 'Max Temp'

# Create a linear regression plot for the Northern Hemisphere
sns.regplot(x=x_column, y=y_column, data=southern_hemi_df, scatter_kws={'alpha': 0.5})

X = sm.add_constant(southern_hemi_df[x_column]) 
model = sm.OLS(southern_hemi_df[y_column], X).fit()

intercept, slope = model.params['const'], model.params[x_column]

# Add labels
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.title('Southern Hemisphere - Linear Regression: {} vs. {}'.format(x_column, y_column))

equation_text = 'Equation: {} = {:.2f} + {:.2f} * {}'.format(y_column, intercept, slope, x_column)
plt.annotate(equation_text, xy=(0.05, 0.95), xycoords='axes fraction', fontsize=10, ha='left')

# Show Plot
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:**
#
# As lat gets closer to 0, temperature becomes higher and higher, hotter to the equator.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_column = 'Lat'
y_column = 'Humidity'

# Create a linear regression plot for the Northern Hemisphere
sns.regplot(x=x_column, y=y_column, data=northern_hemi_df, scatter_kws={'alpha': 0.5})

X = sm.add_constant(northern_hemi_df[x_column]) 
model = sm.OLS(northern_hemi_df[y_column], X).fit()

intercept, slope = model.params['const'], model.params[x_column]

# Add labels
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.title('Northern Hemisphere - Linear Regression: {} vs. {}'.format(x_column, y_column))

equation_text = 'Equation: {} = {:.2f} + {:.2f} * {}'.format(y_column, intercept, slope, x_column)
plt.annotate(equation_text, xy=(0.05, 0.95), xycoords='axes fraction', fontsize=10, ha='left')

# Show Plot
plt.show()

# %%
# Southern Hemisphere Columns
x_column = 'Lat'
y_column = 'Humidity'

# Create a linear regression plot for the Southern Hemisphere
sns.regplot(x=x_column, y=y_column, data=southern_hemi_df, scatter_kws={'alpha': 0.5})

X = sm.add_constant(northern_hemi_df[x_column]) 
model = sm.OLS(northern_hemi_df[y_column], X).fit()

intercept, slope = model.params['const'], model.params[x_column]

# Add Labels
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.title('Southern Hemisphere - Linear Regression: {} vs. {}'.format(x_column, y_column))

equation_text = 'Equation: {} = {:.2f} + {:.2f} * {}'.format(y_column, intercept, slope, x_column)
plt.annotate(equation_text, xy=(0.05, 0.95), xycoords='axes fraction', fontsize=10, ha='left')

# Show Plot
plt.show()

# %% [markdown]
# **Discussion about the linear relationship: Humidity has not significant relation between humidy and linear regression.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere Columns
x_column = 'Lat'
y_column = 'Cloudiness'

# Create a linear regression plot for the Northern Hemisphere
sns.regplot(x=x_column, y=y_column, data=northern_hemi_df, scatter_kws={'alpha': 0.5})

X = sm.add_constant(northern_hemi_df[x_column]) 
model = sm.OLS(northern_hemi_df[y_column], X).fit()

intercept, slope = model.params['const'], model.params[x_column]

# Add Labels
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.title('Northern Hemisphere - Linear Regression: {} vs. {}'.format(x_column, y_column))

equation_text = 'Equation: {} = {:.2f} + {:.2f} * {}'.format(y_column, intercept, slope, x_column)
plt.annotate(equation_text, xy=(0.05, 0.95), xycoords='axes fraction', fontsize=10, ha='left')

# Show Plot
plt.show()

# %%
# Southern Hemisphere Columns
x_column = 'Lat'
y_column = 'Cloudiness'

# Create a linear regression plot for the Southern Hemisphere
sns.regplot(x=x_column, y=y_column, data=southern_hemi_df, scatter_kws={'alpha': 0.5})

X = sm.add_constant(northern_hemi_df[x_column]) 
model = sm.OLS(northern_hemi_df[y_column], X).fit()

intercept, slope = model.params['const'], model.params[x_column]

# Add Labels
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.title('Southern Hemisphere - Linear Regression: {} vs. {}'.format(x_column, y_column))

equation_text = 'Equation: {} = {:.2f} + {:.2f} * {}'.format(y_column, intercept, slope, x_column)
plt.annotate(equation_text, xy=(0.05, 0.95), xycoords='axes fraction', fontsize=10, ha='left')

# Show Plot
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** As lat approaches 0, cloudiness is more likely to appear.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere Columns
x_column = 'Lat'
y_column = 'Wind Speed'

# Create a linear regression plot for the Northern Hemisphere
sns.regplot(x=x_column, y=y_column, data=northern_hemi_df, scatter_kws={'alpha': 0.5})

X = sm.add_constant(northern_hemi_df[x_column]) 
model = sm.OLS(northern_hemi_df[y_column], X).fit()

intercept, slope = model.params['const'], model.params[x_column]

# Add labels
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.title('Northern Hemisphere - Linear Regression: {} vs. {}'.format(x_column, y_column))

equation_text = 'Equation: {} = {:.2f} + {:.2f} * {}'.format(y_column, intercept, slope, x_column)
plt.annotate(equation_text, xy=(0.05, 0.95), xycoords='axes fraction', fontsize=10, ha='left')

# Show Plot
plt.show()

# %%
# Southern Hemisphere Columns
x_column = 'Lat'
y_column = 'Wind Speed'

# Create a linear regression plot for the Southern Hemisphere
sns.regplot(x=x_column, y=y_column, data=southern_hemi_df, scatter_kws={'alpha': 0.5})

X = sm.add_constant(northern_hemi_df[x_column]) 
model = sm.OLS(northern_hemi_df[y_column], X).fit()

intercept, slope = model.params['const'], model.params[x_column]

# Add Labels
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.title('Southern Hemisphere - Linear Regression: {} vs. {}'.format(x_column, y_column))

equation_text = 'Equation: {} = {:.2f} + {:.2f} * {}'.format(y_column, intercept, slope, x_column)
plt.annotate(equation_text, xy=(0.05, 0.95), xycoords='axes fraction', fontsize=10, ha='left')

# Show Plots
# Out:
# Text(0.05, 0.95, 'Equation: Wind Speed = 2.80 + 0.02 * Lat')

# %% [markdown]
# **Discussion about the linear relationship:** Wind speed is lower as lat approaches 0.
